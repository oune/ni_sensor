# %%
import csv

# %%
f = open('vib_test_cDAQ1Mod1_ai0.csv','r')
rdr = csv.reader(f)

# %%
data = []
for line in rdr:
    data.extend(line)

# %%
data
# Out:
# ['-5.177024999999999e-05',
#  '-8.592744999999997e-05',
#  '-9.080704999999999e-05',
#  '-3.2861799999999984e-05',
#  '-8.043789999999998e-05',
#  '-2.9812049999999995e-05',
#  '-0.00011337519999999998',
#  '-4.201104999999998e-05',
#  '-4.5060799999999994e-05',
#  '-0.00010971549999999997',
#  '-0.00012984385',
#  '-7.738815e-05',
#  '-8.470754999999998e-05',
#  '-0.00011520504999999998',
#  '-2.9812049999999995e-05',
#  '-3.103194999999998e-05',
#  '-5.421004999999999e-05',
#  '-8.775729999999997e-05',
#  '-3.3471749999999976e-05',
#  '-7.616824999999998e-05',
#  '-0.00014692245',
#  '-0.00010056624999999998',
#  '-0.00011154534999999997',
#  '-0.00010971549999999997',
#  '-1.0293649999999982e-05',
#  '-5.421004999999999e-05',
#  '-4.811054999999998e-05',
#  '-0.00010666574999999998',
#  '-0.00010117619999999997',
#  '-0.00010910554999999998',
#  '-4.5670749999999986e-05',
#  '-9.202694999999997e-05',
#  '-6.213939999999997e-05',
#  '-1.2733449999999979e-05',
# ...
